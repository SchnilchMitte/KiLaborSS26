# %% [markdown]
# # Test Log

# %% [markdown]
# ## Setup
#
# ### Model candidates
#
# - Increasing numbers equals chronological order. `v3, v4, v5, v6, v7, v8, v9, v10, 11, 26`
# - Starting `v8` first explicitly mentioned as solution to oriented-bounding-box problem
# - Models have different sizes `n, s, m, l, x` (in increasing order of size and amount of parameters)
#
# Considerations
# - "Small" dataset compared to parameter count may overfit (?)
# - VRAM/RAM limits `Model Size + Image Size x Batch`
#     - Big model + large images may run out of memory
# - Smaller size is faster for prototyping
#
# ### Data set
#
# DOTA v1 from https://github.com/ultralytics/assets/releases/tag/v0.0.0
# - Uses predefined split (train, val, test)

# %%
from ultralytics import YOLO
model = YOLO('yolov8n-obb.pt')
model
# Out:
# YOLO(
#   (model): OBBModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
ckpt = model.ckpt
import json
def pprint(s):
    parsed = json.dumps(s, indent=4)
    print(parsed)

print("\nTrainingsargumente:")
pprint(ckpt.get("train_args", {}))

print("\nTrainingsmetriken:")
pprint(ckpt.get("train_metrics", {}))
# Out:
# Trainingsargumente:
# {
#     "task": "obb",
#     "mode": "train",
#     "model": "yolov8n-obb.yaml",
#     "data": "runs/DOTAv1.0-ms.yaml",
#     "epochs": 200,
#     "time": null,
#     "patience": 50,
#     "batch": 32,
#     "imgsz": 1024,
#     "save": true,
#     "save_period": -1,
#     "cache": "disk",
#     "device": 6,
#     "workers": 8,
#     "project": "yolov8-obb",
#     "name": "n-ms-mixup0.1-fixed",
#     "exist_ok": false,
#     "pretrained": true,
#     "optimizer": "auto",
#     "verbose": true,
#     "seed": 0,
#     "deterministic": true,
#     "single_cls": false,
#     "rect": false,
#     "cos_lr": false,
#     "close_mosaic": 0,
#     "resume": false,
#     "amp": true,
#     "fraction": 1.0,
#     "profile": false,
#     "freeze": null,
#     "multi_scale": false,
#     "overlap_mask": true,
#     "mask_ratio": 4,
#     "dropout": 0.0,
#     "val": true,
#     "split": "val",
#     "save_json": false,
#     "save_hybrid": false,
#     "conf": 0.01,
# ...

# %%
results = model.train(data="DOTAv1.yaml", epochs=20, imgsz=1024//2)

# %% [markdown]
# ## Train runs
#
# ### epochs=5 imgsz=1024
#
# Crashed. Running into memory problems.
#
# ### epochs=5 imgsz=256 `train-9`
#
# Barely detects anything.
#
# ### epochs=20 imgsz=512 `train`
#
# - Took 11minutes
# - "Looks like something"
#
# Notes on results:
# - Still gets a lot of things wrong
# - particularly small objects seem to not get recognized at all
#     - is the resolution too small?
# - Very obvious plane in `val_batch2/P1138.jpg` is not being recognized
#
# ### Others
#
# #### Pretrained, 1 epoch imgsz=1024
#
# `P9049.jpg` labels have no swimming pool.
# Model predicts swimming pool
